# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df['age'].mean()
# Out:
# 54.420529801324506

# %%
df['sex'].value_counts(normalize=True)
# Out:
# 1    0.682119
# 0    0.317881
# Name: sex, dtype: float64

# %%
df.groupby('sex')['output'].value_counts()
# Out:
# sex  output
# 0    1          72
#      0          24
# 1    0         114
#      1          92
# Name: output, dtype: int64

# %%
df[df['output'] == 1].groupby('sex')['output'].value_counts()
# Out:
# sex  output
# 0    1         72
# 1    1         92
# Name: output, dtype: int64

# %%
df['output'].count()
# Out:
# 302

# %%
plt.figure(figsize=(8,6))

my_ticks = ['Female', 'Male']

ax = sns.countplot(x='sex', data=df, palette='viridis')
ax.set_xticklabels(my_ticks)
plt.xlabel('Sex')
plt.ylabel('Count')

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{round(height*100/302,2)}%', (x + width/2, y + height), ha='center')

plt.show()

# %%
sns.countplot(x='output', data=df)
# Out:
# <AxesSubplot:xlabel='output', ylabel='count'>

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df['output'].value_counts(normalize=True)
# Out:
# 1    0.543046
# 0    0.456954
# Name: output, dtype: float64

# %%
df['output'].value_counts().values
# Out:
# array([164, 138])

# %%
plt.figure(figsize=(8,6))

sns.set(font_scale=1.3)
sns.countplot(x = 'output', hue='sex', data=df)

plt.xlabel('Output')
plt.ylabel('Count')

plt.show()

# %%
plt.figure(figsize=(8,7))

sns.set_theme()
sns.displot(x='age', data=df, color='Plum', height=7, aspect=1.1)

plt.show()

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df['cp'].value_counts()
# Out:
# 0    143
# 2     86
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
sns.relplot(x="age", y="chol", hue="sex", alpha=.5, palette="muted", sizes=50,
            height=6, data=df)

# %%
sns.lineplot(x="age", y="chol", hue="sex", data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
sns.pairplot(data=df, hue='output')

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
sns.scatterplot(x='fbs', y='output', data=df)
# Out:
# <AxesSubplot:xlabel='fbs', ylabel='output'>

# %%
sns.histplot(df, x='chol', hue='output')
# Out:
# <AxesSubplot:xlabel='chol', ylabel='Count'>

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
cat = ['sex', 'cp', 'fbs', 'restecg', 'exng', 'slp', 'caa', 'thall']



for i in range(len(cat)):
    
    plt.figure(figsize=(20,55))
    
    plt.subplot(len(cat),2,1)
    sns.countplot(x=cat[i] , data=df, palette='mako')
    plt.xlabel(cat[i].capitalize(), fontsize=20)
    plt.ylabel('Count', fontsize=20)
    
    plt.subplot(len(cat),2,2)
    sns.countplot(x=cat[i], hue='output', data = df, palette='magma_r')
    plt.xlabel(cat[i].capitalize(), fontsize=20)
    plt.ylabel('Count', fontsize=20)
    plt.legend(title = 'Output')
    
    plt.show()

# %%
'caa'.capitalize()
# Out:
# 'Caa'

# %%
df.groupby('age')['output'].value_counts()
# Out:
# age  output
# 29   1         1
# 34   1         2
# 35   0         2
#      1         2
# 37   1         2
#               ..
# 70   1         1
# 71   1         3
# 74   1         1
# 76   1         1
# 77   0         1
# Name: output, Length: 75, dtype: int64

# %%
v = pd.crosstab(df["age"],df["output"]).reset_index()

# %%
v.columns = ['Age', 'Low Risk', 'High Risk']

# %%
v.head()
# Out:
#    Age  Low Risk  High Risk
# 0   29         0          1
# 1   34         0          2
# 2   35         2          2
# 3   37         0          2
# 4   38         1          1

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x = 'Age', y='Low Risk', data=v, 
             marker = 'o' ,color = 'darkgreen', ls = '--', lw=2)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Low Risk'>

# %%
plt.figure(figsize=(12,8))

sns.lineplot(x = 'Age', y='High Risk', data=v, 
             marker = 'o', color = 'darkgreen', ls = '--', lw=2)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='High Risk'>

# %%
plt.figure(figsize=(12,8))

sns.lineplot(x='age', y='trtbps', hue='output', ci=0,
             data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='trtbps'>

# %%
plt.figure(figsize=(12,8))

sns.lineplot(x='age', y='thalachh', ci=0,
             data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='thalachh'>

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
cont = ['age', 'trtbps', 'chol', 'thalachh', 'oldpeak']


for i in range(len(cont)):
    
    plt.figure(figsize=(20,40))
    
    plt.subplot(len(cont),2,1)
    sns.histplot(x=cont[i] , data=df, color='Olive', kde=True)
    plt.xlabel(cont[i].capitalize(), fontsize=20)
    plt.ylabel('Count', fontsize=20)
    
    plt.subplot(len(cont),2,2)
    sns.histplot(x=cont[i], hue='output', data = df, palette='magma_r', kde=True)
    plt.xlabel(cont[i].capitalize(), fontsize=20)
    plt.ylabel('Count', fontsize=20)
    
    plt.show()

# %%
plt.figure(figsize=(20,7))

sns.heatmap(df.corr(), annot=True, cmap='coolwarm')

plt.show()

# %%
plt.figure(figsize=(12,8))

sns.stripplot(x='output', y='thalachh',
             data=df)
# Out:
# <AxesSubplot:xlabel='output', ylabel='thalachh'>

# %%
pair = df[['age', 'trtbps', 'chol', 'thalachh', 'oldpeak', 'output']]


sns.pairplot(pair, hue='output', palette='rocket')

plt.show()
